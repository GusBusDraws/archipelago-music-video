# %% [markdown]
# # Import packages

# %%
# Standard library imports
from pathlib import Path
# Third-party library imports
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile

# %% [markdown]
# # Load data

# %%
project_path = Path('..')
wav_path = Path(project_path / 'TDL_Archipelago REF2-01.wav')
samplerate, data = wavfile.read(wav_path)
# Out:
# <ipython-input-5-d335ddac6445>:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read(wav_path)

# %%
print(f"number of channels = {data.shape[1]}")
length = data.shape[0] / samplerate
print(f"length = {length} s")
# Out:
# number of channels = 2
# length = 148.24770975056688 s

# %%
time = np.linspace(0., length, data.shape[0])
fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(time, data[:, 0], label="Left channel")
ax.plot(time, data[:, 1], label="Right channel")
ax.legend(loc='upper right')
ax.set_xlabel("Time (s)")
ax.set_ylabel("Amplitude")
plt.show()
